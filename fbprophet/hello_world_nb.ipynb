# %%
# %run hello_world.py
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">time to read csv: <span style="color: #00ff00; font-weight: bold">0:00:00</span>.<span style="color: #000080; font-weight: bold">184196</span>
#
# shape: <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">251820</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">working dataset for prohpet:
#         date  daily_sign_ups
# ...

# %%
import hello_world
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">time to read csv: <span style="color: #00ff00; font-weight: bold">0:00:00</span>.<span style="color: #000080; font-weight: bold">188266</span>
#
# shape: <span style="font-weight: bold">(</span><span style="color: #000080; font-weight: bold">251820</span>, <span style="color: #000080; font-weight: bold">2</span><span style="font-weight: bold">)</span>
#
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">working dataset for prohpet:
#         date  daily_sign_ups
# ...
